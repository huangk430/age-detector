# %% [markdown]
# # Model Visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


v1_history = pd.read_csv('server/cnn/model_versions/v1/model-training-history.csv')
v2_history = pd.read_csv('server/cnn/model_versions/v2/model-training-history.csv')

# %% [markdown]
# ### Training vs Validation Loss (V1)

# %%
epochs = v1_history['epoch']
training_loss = v1_history['loss']
validation_loss = v1_history['val_loss']

plt.plot(epochs, training_loss, 'b', label='Training Loss')
plt.plot(epochs, validation_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Training vs Validation MSE (V1)

# %%
training_mse = v1_history['mse']
validation_mse = v1_history['val_mse']

plt.plot(epochs, training_mse, 'b', label='Training MSE')
plt.plot(epochs, validation_mse, 'r', label='Validation MSE')
plt.title('Training and Validation Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# ### Training vs Validation MAE (V1)

# %%
training_mae = v1_history['mae']
validation_mae = v1_history['val_mae']

plt.plot(epochs, training_mae, 'b', label='Training MAE')
plt.plot(epochs, validation_mae, 'r', label='Validation MAE')
plt.title('Training and Validation Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Test Results (V1)

# %%
data = pd.read_csv('server/cnn/model_versions/v1/test_results.csv')

predicted_ages = data['Predictions']
true_ages = data['True Targets']

errors = abs(true_ages - predicted_ages)

mse = np.mean((predicted_ages - true_ages)**2)
mae = np.mean(np.abs(predicted_ages - true_ages))

print("Mean Square Error: ", mse)
print("Mean Absolute Error: ", mae)
# Out:
# Mean Square Error:  131.1076935435334
# Mean Absolute Error:  8.710756883333334

# %%
plt.figure(figsize=(8, 6))
plt.scatter(true_ages, predicted_ages, color='blue', alpha=0.5)  # Scatter plot of true age vs predicted age
plt.plot([min(true_ages), max(true_ages)], [min(true_ages), max(true_ages)], color='red', linestyle='--')  # Diagonal line for perfect prediction
plt.title('True Age vs Predicted Age')
plt.xlabel('True Age')
plt.ylabel('Predicted Age')
plt.grid(True)
plt.show()

# %% [markdown]
# As predicted, our model performed the best throughout the ages of 20 - 60, the range where the predicted age matched closer with the true age. The model performed worse with ages that were less than 20 or above 60. Interestingly, it seems like the model started most of its predictions at 23 years old, as we see not many predicted ages below the age of 23 years old. This may be due to a lack of data of ages 0-23 in the dataset we used to train the model, which we could help mediate in the future with data augmentation and synthetic image aging techniques. Also, the dataset we used was highly skewed with its distribution of ages.

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(errors, vert=False)
plt.title('Boxplot of Errors')
plt.xlabel('Error')
plt.grid(True)
plt.show()

# Calculate statistics
mean_error = np.mean(errors)
median_error = np.median(errors)
std_dev_error = np.std(errors)
min_error = np.min(errors)
max_error = np.max(errors)

# Print statistics
print(f"Mean Error: {mean_error}")
print(f"Median Error: {median_error}")
print(f"Standard Deviation of Errors: {std_dev_error}")
print(f"Minimum Error: {min_error}")
print(f"Maximum Error: {max_error}")
# Out:
# Mean Error: 8.710756883333334
# Median Error: 6.914207500000002
# Standard Deviation of Errors: 7.431716360504776
# Minimum Error: 0.00613400000000297
# Maximum Error: 57.352652

# %% [markdown]
# In conclusion, our age model had a mean error of 8.7, and performed the best on ages 20-60.

# %% [markdown]
# ### Training vs Validation Loss (V2)

# %%
epochs = v2_history['epoch']
training_loss = v2_history['loss']
validation_loss = v2_history['val_loss']

plt.plot(epochs, training_loss, 'b', label='Training Loss')
plt.plot(epochs, validation_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Training vs Validation MSE (V2)

# %%
training_mse = v2_history['mse']
validation_mse = v2_history['val_mse']

plt.plot(epochs, training_mse, 'b', label='Training MSE')
plt.plot(epochs, validation_mse, 'r', label='Validation MSE')
plt.title('Training and Validation Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# ### Training vs Validation MAE (V2)

# %%
training_mae = v2_history['mae']
validation_mae = v2_history['val_mae']

plt.plot(epochs, training_mae, 'b', label='Training MAE')
plt.plot(epochs, validation_mae, 'r', label='Validation MAE')
plt.title('Training and Validation Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Test Results (V2)

# %%
data = pd.read_csv('server/cnn/model_versions/v2/test_results.csv')

predicted_ages = data['Predictions']
true_ages = data['True Targets']

errors = abs(true_ages - predicted_ages)

mse = np.mean((predicted_ages - true_ages)**2)
mae = np.mean(np.abs(predicted_ages - true_ages))

print("Mean Square Error: ", mse)
print("Mean Absolute Error: ", mae)
# Out:
# Mean Square Error:  112.71109068359625
# Mean Absolute Error:  7.753673438541666

# %%
plt.figure(figsize=(8, 6))
plt.scatter(true_ages, predicted_ages, color='blue', alpha=0.5)  # Scatter plot of true age vs predicted age
plt.plot([min(true_ages), max(true_ages)], [min(true_ages), max(true_ages)], color='red', linestyle='--')  # Diagonal line for perfect prediction
plt.title('True Age vs Predicted Age')
plt.xlabel('True Age')
plt.ylabel('Predicted Age')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(errors, vert=False)
plt.title('Boxplot of Errors')
plt.xlabel('Error')
plt.grid(True)
plt.show()

# Calculate statistics
mean_error = np.mean(errors)
median_error = np.median(errors)
std_dev_error = np.std(errors)
min_error = np.min(errors)
max_error = np.max(errors)

# Print statistics
print(f"Mean Error: {mean_error}")
print(f"Median Error: {median_error}")
print(f"Standard Deviation of Errors: {std_dev_error}")
print(f"Minimum Error: {min_error}")
print(f"Maximum Error: {max_error}")
# Out:
# Mean Error: 7.753673438541666
# Median Error: 5.9534375000000015
# Standard Deviation of Errors: 7.252009300328405
# Minimum Error: 0.004565999999996961
# Maximum Error: 52.9083
